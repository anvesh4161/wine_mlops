# %%
import os

# %%
pwd
# Out:
# 'e:\\Replica\\wine_mlops\\research'

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'e:\\Replica\\wine_mlops'

# %%
import pandas as pd

# %%
data = pd.read_csv('artifacts/data_ingestion/winequality-red.csv')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataValidationConfig:
    root_dir: Path
    STATUS_FILE: str
    unzip_data_dir: Path
    all_schema: dict

# %%
from wine_quality.constants import *
from wine_quality.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath= CONFIG_FILE_PATH,
        params_filepath=PARAMS_FILE_PATH,
        schema_filepath= SCHEMA_FILE_PATH ):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_validation_config(self) -> DataValidationConfig:
        config = self.config.data_validation
        params = self.params.data_validation
        schema = self.schema.COLUMNS

        create_directories([config.root_dir])

        data_validation_config = DataValidationConfig(
            root_dir=config.root_dir,
            STATUS_FILE=config.STATUS_FILE,
            unzip_data_dir=config.unzip_data_dir,
            all_schema=schema
        )

        return data_validation_config

# %%
import os
from wine_quality import logger

# %%
class DataValidation:
    def __init__(self, config: DataValidationConfig):
        slef.config = config

    def validate_all_columns(self) -> bool:
        """
        Validate all columns in the dataset against the schema
        """
        try:
            validation_status = None
            data = pd.read_csv(self.config.unzip_data_dir)
            all_columns = self.config.all_schema.keys()

            all_schema = self.config.all_schema.keys()

            for column in all_columns:
                if column not in all_schema:
                    validation_status = False
                    logger.info(f"Column {column} is not in the schema")
                    with open(self.config.STATUS_FILE, 'w') as f:
                        f.write(f"Column {column} is not in the schema\n")

                else:
                    validation_status = True
                    logger.info(f"Column {column} is in the schema")
                    with open(self.config.STATUS_FILE, 'w') as f:
                        f.write(f"Column {column} is in the schema\n")

            return validation_status

        except Exception as e:
            raise e

# %%
try:
    config = ConfigurationManager()
    data_validation_config = config.get_data_validation_config()
    data_validation = DataValidation(config=data_validation_config)
    data_validation.validate_all_columns()

except Exception as e:
    raise e
# Out:
# [2025-05-01 06:58:47,363: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-05-01 06:58:47,365: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-05-01 06:58:47,369: INFO: common: yaml file: schema.yaml loaded successfully]
# [2025-05-01 06:58:47,371: INFO: common: created directory at: artifacts]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\anaconda3\envs\wine\lib\site-packages\box\box.py:503, in box.box.Box.__getitem__()
#
# KeyError: 'data_validation'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File c:\Users\HP\anaconda3\envs\wine\lib\site-packages\box\box.py:536, in box.box.Box.__getattr__()
#
# File c:\Users\HP\anaconda3\envs\wine\lib\site-packages\box\box.py:524, in box.box.Box.__getitem__()
#
# BoxKeyError: "'data_validation'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File c:\Users\HP\anaconda3\envs\wine\lib\site-packages\box\box.py:538, in box.box.Box.__getattr__()
#
# AttributeError: 'ConfigBox' object has no attribute 'data_validation'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File c:\Users\HP\anaconda3\envs\wine\lib\site-packages\box\config_box.py:28, in box.config_box.ConfigBox.__getattr__()
#
# File c:\Users\HP\anaconda3\envs\wine\lib\site-packages\box\box.py:552, in box.box.Box.__getattr__()
#
# BoxKeyError: "'ConfigBox' object has no attribute 'data_validation'"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\anaconda3\envs\wine\lib\site-packages\box\box.py:503, in box.box.Box.__getitem__()
#
# KeyError: 'data_validation'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File c:\Users\HP\anaconda3\envs\wine\lib\site-packages\box\box.py:536, in box.box.Box.__getattr__()
#
# File c:\Users\HP\anaconda3\envs\wine\lib\site-packages\box\box.py:524, in box.box.Box.__getitem__()
#
# BoxKeyError: "'data_validation'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File c:\Users\HP\anaconda3\envs\wine\lib\site-packages\box\box.py:538, in box.box.Box.__getattr__()
#
# AttributeError: 'ConfigBox' object has no attribute 'data_validation'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# Cell In[17], line 8
#       5     data_validation.validate_all_columns()
#       7 except Exception as e:
# ----> 8     raise e
#
# Cell In[17], line 3
#       1 try:
#       2     config = ConfigurationManager()
# ----> 3     data_validation_config = config.get_data_validation_config()
#       4     data_validation = DataValidation(config=data_validation_config)
#       5     data_validation.validate_all_columns()
#
# Cell In[13], line 16, in ConfigurationManager.get_data_validation_config(self)
#      14 def get_data_validation_config(self) -> DataValidationConfig:
#      15     config = self.config.data_validation
# ---> 16     params = self.params.data_validation
#      17     schema = self.schema.COLUMNS
#      19     create_directories([config.root_dir])
#
# File c:\Users\HP\anaconda3\envs\wine\lib\site-packages\box\config_box.py:30, in box.config_box.ConfigBox.__getattr__()
#
# File c:\Users\HP\anaconda3\envs\wine\lib\site-packages\box\box.py:552, in box.box.Box.__getattr__()
#
# BoxKeyError: "'ConfigBox' object has no attribute 'data_validation'"
